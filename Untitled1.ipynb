# %%
print("Hello World")
# Out:
# Hello World

# %%
A = 6
B = 3;
C = A + B;
print(C)
# Out:
# 9

# %%
a = int(input('Введите знечение 1: '));
b = int(input('Введите значение 2: '));
c = int(input('Введите значение 3: '));
x = (a**2 + b**2 - c**3)/2
print(x)
# Out:
# Введите знечение 1: 6
# Введите значение 2: 2
# Введите значение 3: 6
# -88.0

# %%
a = 5
b = int(input('Введите число: '));
b = a * b
print(b)
# Out:
# Введите число: 5
# 25

# %%
a = int(input("Введите число: "));
b = int(input("Введите число: "));
summa = (a*b)**2;
print(summa)
# Out:
# Введите число: 1
# Введите число: 2
# 4

# %%
a = 15
b = 10
c = int(input("Введите число: "));
x = (a+b)/c;
print(x)
# Out:
# Введите число: 5
# 5.0

# %%
a = int(input('Введите число:' ))
b = int(input('Введите число: '))
c = (a+b)**2;
print(c)
# Out:
# Введите число:10
# Введите число: 10
# 400

# %%
a = int(input('Введите число:' ))
b = int(input('Введите число:' ))
c = int(input('Введите число:' ))
P = (2*a) + b
S = (a*b)/2
print(P,S)
# Out:
# Введите число:2
# Введите число:2
# Введите число:2
# 6 2.0

# %%
a = int(input('Введите число:' ))
b = int(input('Введите число:' ))
C = ((a**3+14)/5)* b
print(C)
# Out:
# Введите число:1
# Введите число:1
# 3.0
