# %%
a = int(input('Введите значение a: '));
if a==1:
        print("Январь")
elif a==2:
        print("Февраль")
elif a==3:
        print("Март")
elif a==4:
        print("Апрель")
elif a==5:
        print("Май")
elif a==6:
        print("Июнь")
elif a==7:
        print("Июль")
elif a==8:
        print("Август")
elif a==9:
        print("Сентябрь")
elif a==10:
        print("Октябрь")
elif a==11:
        print("Ноябрь")
elif a==12:
        print("Декабрь")
# Out:
# Введите значение a: 5
# Май

# %%
x=int(input())
if x%2==0: print("четное")
else: print("нечетное")
# Out:
# 9
# нечетное

# %%
N=int(input())
if N<40: print("not stonks")
if N>40: print("stonks")
if N==40: print("ravno")
# Out:
# 40
# ravno

# %%
is_year_leap=int(input())
if is_year_leap%4==0: print("True")
elif is_year_leap%4 !=0: print("False")
# Out:
# 2020
# True

# %%
from sympy import *
isprime(5)
# Out:
# True

# %%
a = float(input())
b = float(input())

if (a / b==3.6) or ((-138 / 2) ** 1.3 <= b <= -69 / 28 ** 5.1 * 4):
  print(a, b)
# Out:
# 7.2
# 2
# 7.2 2.0

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
if a!=b!=c!=d!=e: print("Все уникальные")
else: print("Не все уникальные")
if a%2==0 and b%2==0 and c%2==0 and d%2==0 and e%2==0: print("Все четные")
else: print("Не все четные")
# Out:
# 5
# 6
# 3
# 10
# 7
# Все уникальные
# Не все четные

# %% [markdown]
# Повышенной сложности:

# %%
a = int(input())
b = int(input())
c = int(input())
z=(((a**2)+(b**3))/(c+3))/4
if z%2==0: print("Четное")
elif z%2!=0: print("Нечетное")
# Out:
# 5
# 8
# 2
# Нечетное
